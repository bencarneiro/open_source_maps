# %%
import pandas as pd
import requests

# %%
pd.set_option('display.max_columns', None)

# %%
bike_data_2010 = requests.get("https://api.census.gov/data/2010/acs/acs5?get=NAME,B01001_001E,B08006_001E,B08006_002E,B08006_003E,B08006_004E,B08006_005E,B08006_006E,B08006_007E,B08006_008E,B08006_009E,B08006_010E,B08006_011E,B08006_012E,B08006_013E,B08006_014E,B08006_015E,B08006_016E,B08006_017E&for=metropolitan%20statistical%20area/micropolitan%20statistical%20area:*")
bike_data_2011 = requests.get("https://api.census.gov/data/2011/acs/acs5?get=NAME,B01001_001E,B08006_001E,B08006_002E,B08006_003E,B08006_004E,B08006_005E,B08006_006E,B08006_007E,B08006_008E,B08006_009E,B08006_010E,B08006_011E,B08006_012E,B08006_013E,B08006_014E,B08006_015E,B08006_016E,B08006_017E&for=metropolitan%20statistical%20area/micropolitan%20statistical%20area:*")
bike_data_2012 = requests.get("https://api.census.gov/data/2012/acs/acs5?get=NAME,B01001_001E,B08006_001E,B08006_002E,B08006_003E,B08006_004E,B08006_005E,B08006_006E,B08006_007E,B08006_008E,B08006_009E,B08006_010E,B08006_011E,B08006_012E,B08006_013E,B08006_014E,B08006_015E,B08006_016E,B08006_017E&for=metropolitan%20statistical%20area/micropolitan%20statistical%20area:*")
bike_data_2013 = requests.get("https://api.census.gov/data/2013/acs/acs5?get=NAME,B01001_001E,B08006_001E,B08006_002E,B08006_003E,B08006_004E,B08006_005E,B08006_006E,B08006_007E,B08006_008E,B08006_009E,B08006_010E,B08006_011E,B08006_012E,B08006_013E,B08006_014E,B08006_015E,B08006_016E,B08006_017E&for=metropolitan%20statistical%20area/micropolitan%20statistical%20area:*")
bike_data_2014 = requests.get("https://api.census.gov/data/2014/acs/acs5?get=NAME,B01001_001E,B08006_001E,B08006_002E,B08006_003E,B08006_004E,B08006_005E,B08006_006E,B08006_007E,B08006_008E,B08006_009E,B08006_010E,B08006_011E,B08006_012E,B08006_013E,B08006_014E,B08006_015E,B08006_016E,B08006_017E&for=metropolitan%20statistical%20area/micropolitan%20statistical%20area:*")
bike_data_2015 = requests.get("https://api.census.gov/data/2015/acs/acs5?get=NAME,B01001_001E,B08006_001E,B08006_002E,B08006_003E,B08006_004E,B08006_005E,B08006_006E,B08006_007E,B08006_008E,B08006_009E,B08006_010E,B08006_011E,B08006_012E,B08006_013E,B08006_014E,B08006_015E,B08006_016E,B08006_017E&for=metropolitan%20statistical%20area/micropolitan%20statistical%20area:*")
bike_data_2016 = requests.get("https://api.census.gov/data/2016/acs/acs5?get=NAME,B01001_001E,B08006_001E,B08006_002E,B08006_003E,B08006_004E,B08006_005E,B08006_006E,B08006_007E,B08006_008E,B08006_009E,B08006_010E,B08006_011E,B08006_012E,B08006_013E,B08006_014E,B08006_015E,B08006_016E,B08006_017E&for=metropolitan%20statistical%20area/micropolitan%20statistical%20area:*")
bike_data_2017 = requests.get("https://api.census.gov/data/2017/acs/acs5?get=NAME,B01001_001E,B08006_001E,B08006_002E,B08006_003E,B08006_004E,B08006_005E,B08006_006E,B08006_007E,B08006_008E,B08006_009E,B08006_010E,B08006_011E,B08006_012E,B08006_013E,B08006_014E,B08006_015E,B08006_016E,B08006_017E&for=metropolitan%20statistical%20area/micropolitan%20statistical%20area:*")
bike_data_2018 = requests.get("https://api.census.gov/data/2018/acs/acs5?get=NAME,B01001_001E,B08006_001E,B08006_002E,B08006_003E,B08006_004E,B08006_005E,B08006_006E,B08006_007E,B08006_008E,B08006_009E,B08006_010E,B08006_011E,B08006_012E,B08006_013E,B08006_014E,B08006_015E,B08006_016E,B08006_017E&for=metropolitan%20statistical%20area/micropolitan%20statistical%20area:*")
bike_data_2019 = requests.get("https://api.census.gov/data/2019/acs/acs5?get=NAME,B01001_001E,B08006_001E,B08006_002E,B08006_003E,B08006_004E,B08006_005E,B08006_006E,B08006_007E,B08006_008E,B08006_009E,B08006_010E,B08006_011E,B08006_012E,B08006_013E,B08006_014E,B08006_015E,B08006_016E,B08006_017E&for=metropolitan%20statistical%20area/micropolitan%20statistical%20area:*")
bike_data_2020 = requests.get("https://api.census.gov/data/2020/acs/acs5?get=NAME,B01001_001E,B08006_001E,B08006_002E,B08006_003E,B08006_004E,B08006_005E,B08006_006E,B08006_007E,B08006_008E,B08006_009E,B08006_010E,B08006_011E,B08006_012E,B08006_013E,B08006_014E,B08006_015E,B08006_016E,B08006_017E&for=metropolitan%20statistical%20area/micropolitan%20statistical%20area:*")
bike_data_2021 = requests.get("https://api.census.gov/data/2021/acs/acs5?get=NAME,B01001_001E,B08006_001E,B08006_002E,B08006_003E,B08006_004E,B08006_005E,B08006_006E,B08006_007E,B08006_008E,B08006_009E,B08006_010E,B08006_011E,B08006_012E,B08006_013E,B08006_014E,B08006_015E,B08006_016E,B08006_017E&for=metropolitan/micropolitan%20statistical%20area:*")

# %%
# df_2010 = pd.read_json(bike_data_2010.text)

# %%
# df_2010 = pd.read_json(bike_data_2010.text)
# df_2010 = df_2010.rename(columns=df_2010.iloc[0])
# df_2010 = df_2010.rename(index=df_2010['metropolitan statistical area/micropolitan statistical area'])
# df_2010 = df_2010.drop(['metropolitan statistical area/micropolitan statistical area'])

# %%
# coding my repetitive code

years = ["2010", "2011", "2012", "2013", "2014", "2015", "2016", "2017", "2018", "2019", "2020", "2021"]
for year in years:
    print(f"df_{year} = pd.read_json(bike_data_{year}.text)")
    print(f"df_{year} = df_{year}.rename(columns=df_{year}.iloc[0])")
    if year == "2021":
        print(f"df_{year} = df_{year}.rename(index=df_{year}['metropolitan/micropolitan statistical area'])")
        print(f"df_{year} = df_{year}.drop(['metropolitan/micropolitan statistical area'])")
    else:
        print(f"df_{year} = df_{year}.rename(index=df_{year}['metropolitan statistical area/micropolitan statistical area'])")
        print(f"df_{year} = df_{year}.drop(['metropolitan statistical area/micropolitan statistical area'])")
# Out:
# df_2010 = pd.read_json(bike_data_2010.text)
# df_2010 = df_2010.rename(columns=df_2010.iloc[0])
# df_2010 = df_2010.rename(index=df_2010['metropolitan statistical area/micropolitan statistical area'])
# df_2010 = df_2010.drop(['metropolitan statistical area/micropolitan statistical area'])
# df_2011 = pd.read_json(bike_data_2011.text)
# df_2011 = df_2011.rename(columns=df_2011.iloc[0])
# df_2011 = df_2011.rename(index=df_2011['metropolitan statistical area/micropolitan statistical area'])
# df_2011 = df_2011.drop(['metropolitan statistical area/micropolitan statistical area'])
# df_2012 = pd.read_json(bike_data_2012.text)
# df_2012 = df_2012.rename(columns=df_2012.iloc[0])
# df_2012 = df_2012.rename(index=df_2012['metropolitan statistical area/micropolitan statistical area'])
# df_2012 = df_2012.drop(['metropolitan statistical area/micropolitan statistical area'])
# df_2013 = pd.read_json(bike_data_2013.text)
# df_2013 = df_2013.rename(columns=df_2013.iloc[0])
# ...

# %%
df_2010 = pd.read_json(bike_data_2010.text)
df_2010 = df_2010.rename(columns=df_2010.iloc[0])
df_2010 = df_2010.rename(index=df_2010['metropolitan statistical area/micropolitan statistical area'])
df_2010 = df_2010.drop(['metropolitan statistical area/micropolitan statistical area'])
df_2011 = pd.read_json(bike_data_2011.text)
df_2011 = df_2011.rename(columns=df_2011.iloc[0])
df_2011 = df_2011.rename(index=df_2011['metropolitan statistical area/micropolitan statistical area'])
df_2011 = df_2011.drop(['metropolitan statistical area/micropolitan statistical area'])
df_2012 = pd.read_json(bike_data_2012.text)
df_2012 = df_2012.rename(columns=df_2012.iloc[0])
df_2012 = df_2012.rename(index=df_2012['metropolitan statistical area/micropolitan statistical area'])
df_2012 = df_2012.drop(['metropolitan statistical area/micropolitan statistical area'])
df_2013 = pd.read_json(bike_data_2013.text)
df_2013 = df_2013.rename(columns=df_2013.iloc[0])
df_2013 = df_2013.rename(index=df_2013['metropolitan statistical area/micropolitan statistical area'])
df_2013 = df_2013.drop(['metropolitan statistical area/micropolitan statistical area'])
df_2014 = pd.read_json(bike_data_2014.text)
df_2014 = df_2014.rename(columns=df_2014.iloc[0])
df_2014 = df_2014.rename(index=df_2014['metropolitan statistical area/micropolitan statistical area'])
df_2014 = df_2014.drop(['metropolitan statistical area/micropolitan statistical area'])
df_2015 = pd.read_json(bike_data_2015.text)
df_2015 = df_2015.rename(columns=df_2015.iloc[0])
df_2015 = df_2015.rename(index=df_2015['metropolitan statistical area/micropolitan statistical area'])
df_2015 = df_2015.drop(['metropolitan statistical area/micropolitan statistical area'])
df_2016 = pd.read_json(bike_data_2016.text)
df_2016 = df_2016.rename(columns=df_2016.iloc[0])
df_2016 = df_2016.rename(index=df_2016['metropolitan statistical area/micropolitan statistical area'])
df_2016 = df_2016.drop(['metropolitan statistical area/micropolitan statistical area'])
df_2017 = pd.read_json(bike_data_2017.text)
df_2017 = df_2017.rename(columns=df_2017.iloc[0])
df_2017 = df_2017.rename(index=df_2017['metropolitan statistical area/micropolitan statistical area'])
df_2017 = df_2017.drop(['metropolitan statistical area/micropolitan statistical area'])
df_2018 = pd.read_json(bike_data_2018.text)
df_2018 = df_2018.rename(columns=df_2018.iloc[0])
df_2018 = df_2018.rename(index=df_2018['metropolitan statistical area/micropolitan statistical area'])
df_2018 = df_2018.drop(['metropolitan statistical area/micropolitan statistical area'])
df_2019 = pd.read_json(bike_data_2019.text)
df_2019 = df_2019.rename(columns=df_2019.iloc[0])
df_2019 = df_2019.rename(index=df_2019['metropolitan statistical area/micropolitan statistical area'])
df_2019 = df_2019.drop(['metropolitan statistical area/micropolitan statistical area'])
df_2020 = pd.read_json(bike_data_2020.text)
df_2020 = df_2020.rename(columns=df_2020.iloc[0])
df_2020 = df_2020.rename(index=df_2020['metropolitan statistical area/micropolitan statistical area'])
df_2020 = df_2020.drop(['metropolitan statistical area/micropolitan statistical area'])
df_2021 = pd.read_json(bike_data_2021.text)
df_2021 = df_2021.rename(columns=df_2021.iloc[0])
df_2021 = df_2021.rename(index=df_2021['metropolitan/micropolitan statistical area'])
df_2021 = df_2021.drop(['metropolitan/micropolitan statistical area'])

# %%
# coding my repetitive code
# rename all the data columns to include the year of the data- preparing them all to be merged

years = ["2010", "2011", "2012", "2013", "2014", "2015", "2016", "2017", "2018", "2019", "2020", "2021"]
for year in years:
    print(f"df_{year} = df_{year}.rename(columns={{'B01001_001E':'B01001_001E_{year}', 'B08006_001E':'B08006_001E_{year}', 'B08006_002E':'B08006_002E_{year}', 'B08006_003E':'B08006_003E_{year}', 'B08006_004E':'B08006_004E_{year}', 'B08006_005E':'B08006_005E_{year}', 'B08006_006E':'B08006_006E_{year}', 'B08006_007E':'B08006_007E_{year}', 'B08006_008E':'B08006_008E_{year}', 'B08006_009E':'B08006_009E_{year}', 'B08006_010E':'B08006_010E_{year}', 'B08006_011E':'B08006_011E_{year}', 'B08006_012E':'B08006_012E_{year}', 'B08006_013E':'B08006_013E_{year}', 'B08006_014E':'B08006_014E_{year}', 'B08006_015E':'B08006_015E_{year}', 'B08006_016E':'B08006_016E_{year}', 'B08006_017E':'B08006_017E_{year}'}})")
# Out:
# df_2010 = df_2010.rename(columns={'B01001_001E':'B01001_001E_2010', 'B08006_001E':'B08006_001E_2010', 'B08006_002E':'B08006_002E_2010', 'B08006_003E':'B08006_003E_2010', 'B08006_004E':'B08006_004E_2010', 'B08006_005E':'B08006_005E_2010', 'B08006_006E':'B08006_006E_2010', 'B08006_007E':'B08006_007E_2010', 'B08006_008E':'B08006_008E_2010', 'B08006_009E':'B08006_009E_2010', 'B08006_010E':'B08006_010E_2010', 'B08006_011E':'B08006_011E_2010', 'B08006_012E':'B08006_012E_2010', 'B08006_013E':'B08006_013E_2010', 'B08006_014E':'B08006_014E_2010', 'B08006_015E':'B08006_015E_2010', 'B08006_016E':'B08006_016E_2010', 'B08006_017E':'B08006_017E_2010'})
# ...

# %%
df_2010 = df_2010.rename(columns={'B01001_001E':'B01001_001E_2010', 'B08006_001E':'B08006_001E_2010', 'B08006_002E':'B08006_002E_2010', 'B08006_003E':'B08006_003E_2010', 'B08006_004E':'B08006_004E_2010', 'B08006_005E':'B08006_005E_2010', 'B08006_006E':'B08006_006E_2010', 'B08006_007E':'B08006_007E_2010', 'B08006_008E':'B08006_008E_2010', 'B08006_009E':'B08006_009E_2010', 'B08006_010E':'B08006_010E_2010', 'B08006_011E':'B08006_011E_2010', 'B08006_012E':'B08006_012E_2010', 'B08006_013E':'B08006_013E_2010', 'B08006_014E':'B08006_014E_2010', 'B08006_015E':'B08006_015E_2010', 'B08006_016E':'B08006_016E_2010', 'B08006_017E':'B08006_017E_2010'})
df_2011 = df_2011.rename(columns={'B01001_001E':'B01001_001E_2011', 'B08006_001E':'B08006_001E_2011', 'B08006_002E':'B08006_002E_2011', 'B08006_003E':'B08006_003E_2011', 'B08006_004E':'B08006_004E_2011', 'B08006_005E':'B08006_005E_2011', 'B08006_006E':'B08006_006E_2011', 'B08006_007E':'B08006_007E_2011', 'B08006_008E':'B08006_008E_2011', 'B08006_009E':'B08006_009E_2011', 'B08006_010E':'B08006_010E_2011', 'B08006_011E':'B08006_011E_2011', 'B08006_012E':'B08006_012E_2011', 'B08006_013E':'B08006_013E_2011', 'B08006_014E':'B08006_014E_2011', 'B08006_015E':'B08006_015E_2011', 'B08006_016E':'B08006_016E_2011', 'B08006_017E':'B08006_017E_2011'})
df_2012 = df_2012.rename(columns={'B01001_001E':'B01001_001E_2012', 'B08006_001E':'B08006_001E_2012', 'B08006_002E':'B08006_002E_2012', 'B08006_003E':'B08006_003E_2012', 'B08006_004E':'B08006_004E_2012', 'B08006_005E':'B08006_005E_2012', 'B08006_006E':'B08006_006E_2012', 'B08006_007E':'B08006_007E_2012', 'B08006_008E':'B08006_008E_2012', 'B08006_009E':'B08006_009E_2012', 'B08006_010E':'B08006_010E_2012', 'B08006_011E':'B08006_011E_2012', 'B08006_012E':'B08006_012E_2012', 'B08006_013E':'B08006_013E_2012', 'B08006_014E':'B08006_014E_2012', 'B08006_015E':'B08006_015E_2012', 'B08006_016E':'B08006_016E_2012', 'B08006_017E':'B08006_017E_2012'})
df_2013 = df_2013.rename(columns={'B01001_001E':'B01001_001E_2013', 'B08006_001E':'B08006_001E_2013', 'B08006_002E':'B08006_002E_2013', 'B08006_003E':'B08006_003E_2013', 'B08006_004E':'B08006_004E_2013', 'B08006_005E':'B08006_005E_2013', 'B08006_006E':'B08006_006E_2013', 'B08006_007E':'B08006_007E_2013', 'B08006_008E':'B08006_008E_2013', 'B08006_009E':'B08006_009E_2013', 'B08006_010E':'B08006_010E_2013', 'B08006_011E':'B08006_011E_2013', 'B08006_012E':'B08006_012E_2013', 'B08006_013E':'B08006_013E_2013', 'B08006_014E':'B08006_014E_2013', 'B08006_015E':'B08006_015E_2013', 'B08006_016E':'B08006_016E_2013', 'B08006_017E':'B08006_017E_2013'})
df_2014 = df_2014.rename(columns={'B01001_001E':'B01001_001E_2014', 'B08006_001E':'B08006_001E_2014', 'B08006_002E':'B08006_002E_2014', 'B08006_003E':'B08006_003E_2014', 'B08006_004E':'B08006_004E_2014', 'B08006_005E':'B08006_005E_2014', 'B08006_006E':'B08006_006E_2014', 'B08006_007E':'B08006_007E_2014', 'B08006_008E':'B08006_008E_2014', 'B08006_009E':'B08006_009E_2014', 'B08006_010E':'B08006_010E_2014', 'B08006_011E':'B08006_011E_2014', 'B08006_012E':'B08006_012E_2014', 'B08006_013E':'B08006_013E_2014', 'B08006_014E':'B08006_014E_2014', 'B08006_015E':'B08006_015E_2014', 'B08006_016E':'B08006_016E_2014', 'B08006_017E':'B08006_017E_2014'})
df_2015 = df_2015.rename(columns={'B01001_001E':'B01001_001E_2015', 'B08006_001E':'B08006_001E_2015', 'B08006_002E':'B08006_002E_2015', 'B08006_003E':'B08006_003E_2015', 'B08006_004E':'B08006_004E_2015', 'B08006_005E':'B08006_005E_2015', 'B08006_006E':'B08006_006E_2015', 'B08006_007E':'B08006_007E_2015', 'B08006_008E':'B08006_008E_2015', 'B08006_009E':'B08006_009E_2015', 'B08006_010E':'B08006_010E_2015', 'B08006_011E':'B08006_011E_2015', 'B08006_012E':'B08006_012E_2015', 'B08006_013E':'B08006_013E_2015', 'B08006_014E':'B08006_014E_2015', 'B08006_015E':'B08006_015E_2015', 'B08006_016E':'B08006_016E_2015', 'B08006_017E':'B08006_017E_2015'})
df_2016 = df_2016.rename(columns={'B01001_001E':'B01001_001E_2016', 'B08006_001E':'B08006_001E_2016', 'B08006_002E':'B08006_002E_2016', 'B08006_003E':'B08006_003E_2016', 'B08006_004E':'B08006_004E_2016', 'B08006_005E':'B08006_005E_2016', 'B08006_006E':'B08006_006E_2016', 'B08006_007E':'B08006_007E_2016', 'B08006_008E':'B08006_008E_2016', 'B08006_009E':'B08006_009E_2016', 'B08006_010E':'B08006_010E_2016', 'B08006_011E':'B08006_011E_2016', 'B08006_012E':'B08006_012E_2016', 'B08006_013E':'B08006_013E_2016', 'B08006_014E':'B08006_014E_2016', 'B08006_015E':'B08006_015E_2016', 'B08006_016E':'B08006_016E_2016', 'B08006_017E':'B08006_017E_2016'})
df_2017 = df_2017.rename(columns={'B01001_001E':'B01001_001E_2017', 'B08006_001E':'B08006_001E_2017', 'B08006_002E':'B08006_002E_2017', 'B08006_003E':'B08006_003E_2017', 'B08006_004E':'B08006_004E_2017', 'B08006_005E':'B08006_005E_2017', 'B08006_006E':'B08006_006E_2017', 'B08006_007E':'B08006_007E_2017', 'B08006_008E':'B08006_008E_2017', 'B08006_009E':'B08006_009E_2017', 'B08006_010E':'B08006_010E_2017', 'B08006_011E':'B08006_011E_2017', 'B08006_012E':'B08006_012E_2017', 'B08006_013E':'B08006_013E_2017', 'B08006_014E':'B08006_014E_2017', 'B08006_015E':'B08006_015E_2017', 'B08006_016E':'B08006_016E_2017', 'B08006_017E':'B08006_017E_2017'})
df_2018 = df_2018.rename(columns={'B01001_001E':'B01001_001E_2018', 'B08006_001E':'B08006_001E_2018', 'B08006_002E':'B08006_002E_2018', 'B08006_003E':'B08006_003E_2018', 'B08006_004E':'B08006_004E_2018', 'B08006_005E':'B08006_005E_2018', 'B08006_006E':'B08006_006E_2018', 'B08006_007E':'B08006_007E_2018', 'B08006_008E':'B08006_008E_2018', 'B08006_009E':'B08006_009E_2018', 'B08006_010E':'B08006_010E_2018', 'B08006_011E':'B08006_011E_2018', 'B08006_012E':'B08006_012E_2018', 'B08006_013E':'B08006_013E_2018', 'B08006_014E':'B08006_014E_2018', 'B08006_015E':'B08006_015E_2018', 'B08006_016E':'B08006_016E_2018', 'B08006_017E':'B08006_017E_2018'})
df_2019 = df_2019.rename(columns={'B01001_001E':'B01001_001E_2019', 'B08006_001E':'B08006_001E_2019', 'B08006_002E':'B08006_002E_2019', 'B08006_003E':'B08006_003E_2019', 'B08006_004E':'B08006_004E_2019', 'B08006_005E':'B08006_005E_2019', 'B08006_006E':'B08006_006E_2019', 'B08006_007E':'B08006_007E_2019', 'B08006_008E':'B08006_008E_2019', 'B08006_009E':'B08006_009E_2019', 'B08006_010E':'B08006_010E_2019', 'B08006_011E':'B08006_011E_2019', 'B08006_012E':'B08006_012E_2019', 'B08006_013E':'B08006_013E_2019', 'B08006_014E':'B08006_014E_2019', 'B08006_015E':'B08006_015E_2019', 'B08006_016E':'B08006_016E_2019', 'B08006_017E':'B08006_017E_2019'})
df_2020 = df_2020.rename(columns={'B01001_001E':'B01001_001E_2020', 'B08006_001E':'B08006_001E_2020', 'B08006_002E':'B08006_002E_2020', 'B08006_003E':'B08006_003E_2020', 'B08006_004E':'B08006_004E_2020', 'B08006_005E':'B08006_005E_2020', 'B08006_006E':'B08006_006E_2020', 'B08006_007E':'B08006_007E_2020', 'B08006_008E':'B08006_008E_2020', 'B08006_009E':'B08006_009E_2020', 'B08006_010E':'B08006_010E_2020', 'B08006_011E':'B08006_011E_2020', 'B08006_012E':'B08006_012E_2020', 'B08006_013E':'B08006_013E_2020', 'B08006_014E':'B08006_014E_2020', 'B08006_015E':'B08006_015E_2020', 'B08006_016E':'B08006_016E_2020', 'B08006_017E':'B08006_017E_2020'})
df_2021 = df_2021.rename(columns={'B01001_001E':'B01001_001E_2021', 'B08006_001E':'B08006_001E_2021', 'B08006_002E':'B08006_002E_2021', 'B08006_003E':'B08006_003E_2021', 'B08006_004E':'B08006_004E_2021', 'B08006_005E':'B08006_005E_2021', 'B08006_006E':'B08006_006E_2021', 'B08006_007E':'B08006_007E_2021', 'B08006_008E':'B08006_008E_2021', 'B08006_009E':'B08006_009E_2021', 'B08006_010E':'B08006_010E_2021', 'B08006_011E':'B08006_011E_2021', 'B08006_012E':'B08006_012E_2021', 'B08006_013E':'B08006_013E_2021', 'B08006_014E':'B08006_014E_2021', 'B08006_015E':'B08006_015E_2021', 'B08006_016E':'B08006_016E_2021', 'B08006_017E':'B08006_017E_2021'})

# %%
commuting_data = df_2010.merge(df_2011, how="inner",right_index=True, left_index=True)
commuting_data = commuting_data.merge(df_2012, how="inner",right_index=True, left_index=True)
commuting_data = commuting_data.merge(df_2013, how="inner",right_index=True, left_index=True)
commuting_data = commuting_data.merge(df_2014, how="inner",right_index=True, left_index=True)
commuting_data = commuting_data.merge(df_2015, how="inner",right_index=True, left_index=True)
commuting_data = commuting_data.merge(df_2016, how="inner",right_index=True, left_index=True)
commuting_data = commuting_data.merge(df_2017, how="inner",right_index=True, left_index=True)
commuting_data = commuting_data.merge(df_2018, how="inner",right_index=True, left_index=True)
commuting_data = commuting_data.merge(df_2019, how="inner",right_index=True, left_index=True)
commuting_data = commuting_data.merge(df_2020, how="inner",right_index=True, left_index=True)
commuting_data = commuting_data.merge(df_2021, how="inner",right_index=True, left_index=True)
commuting_data = commuting_data.loc[:,~commuting_data.columns.duplicated()].copy()
commuting_data = commuting_data.rename(columns={"NAME_x": "NAME"})
# Out:
# /tmp/ipykernel_70256/621530752.py:3: FutureWarning: Passing 'suffixes' which cause duplicate columns {'metropolitan statistical area/micropolitan statistical area_x', 'NAME_x'} in the result is deprecated and will raise a MergeError in a future version.
#   commuting_data = commuting_data.merge(df_2013, how="inner",right_index=True, left_index=True)
# /tmp/ipykernel_70256/621530752.py:5: FutureWarning: Passing 'suffixes' which cause duplicate columns {'metropolitan statistical area/micropolitan statistical area_x', 'NAME_x'} in the result is deprecated and will raise a MergeError in a future version.
#   commuting_data = commuting_data.merge(df_2015, how="inner",right_index=True, left_index=True)
# /tmp/ipykernel_70256/621530752.py:7: FutureWarning: Passing 'suffixes' which cause duplicate columns {'metropolitan statistical area/micropolitan statistical area_x', 'NAME_x'} in the result is deprecated and will raise a MergeError in a future version.
# ...

# %%
# writing code to write my code
# nullify all the Naan values by converting our numbers to numbers not strings

for column in commuting_data.columns:
    if column[0] == "B":
        print(f"commuting_data['{column}'] = pd.to_numeric(commuting_data['{column}'])")
# Out:
# commuting_data['B01001_001E_2010'] = pd.to_numeric(commuting_data['B01001_001E_2010'])
# commuting_data['B08006_001E_2010'] = pd.to_numeric(commuting_data['B08006_001E_2010'])
# commuting_data['B08006_002E_2010'] = pd.to_numeric(commuting_data['B08006_002E_2010'])
# commuting_data['B08006_003E_2010'] = pd.to_numeric(commuting_data['B08006_003E_2010'])
# commuting_data['B08006_004E_2010'] = pd.to_numeric(commuting_data['B08006_004E_2010'])
# commuting_data['B08006_005E_2010'] = pd.to_numeric(commuting_data['B08006_005E_2010'])
# commuting_data['B08006_006E_2010'] = pd.to_numeric(commuting_data['B08006_006E_2010'])
# commuting_data['B08006_007E_2010'] = pd.to_numeric(commuting_data['B08006_007E_2010'])
# commuting_data['B08006_008E_2010'] = pd.to_numeric(commuting_data['B08006_008E_2010'])
# commuting_data['B08006_009E_2010'] = pd.to_numeric(commuting_data['B08006_009E_2010'])
# commuting_data['B08006_010E_2010'] = pd.to_numeric(commuting_data['B08006_010E_2010'])
# ...

# %%
commuting_data['B01001_001E_2010'] = pd.to_numeric(commuting_data['B01001_001E_2010'])
commuting_data['B08006_001E_2010'] = pd.to_numeric(commuting_data['B08006_001E_2010'])
commuting_data['B08006_002E_2010'] = pd.to_numeric(commuting_data['B08006_002E_2010'])
commuting_data['B08006_003E_2010'] = pd.to_numeric(commuting_data['B08006_003E_2010'])
commuting_data['B08006_004E_2010'] = pd.to_numeric(commuting_data['B08006_004E_2010'])
commuting_data['B08006_005E_2010'] = pd.to_numeric(commuting_data['B08006_005E_2010'])
commuting_data['B08006_006E_2010'] = pd.to_numeric(commuting_data['B08006_006E_2010'])
commuting_data['B08006_007E_2010'] = pd.to_numeric(commuting_data['B08006_007E_2010'])
commuting_data['B08006_008E_2010'] = pd.to_numeric(commuting_data['B08006_008E_2010'])
commuting_data['B08006_009E_2010'] = pd.to_numeric(commuting_data['B08006_009E_2010'])
commuting_data['B08006_010E_2010'] = pd.to_numeric(commuting_data['B08006_010E_2010'])
commuting_data['B08006_011E_2010'] = pd.to_numeric(commuting_data['B08006_011E_2010'])
commuting_data['B08006_012E_2010'] = pd.to_numeric(commuting_data['B08006_012E_2010'])
commuting_data['B08006_013E_2010'] = pd.to_numeric(commuting_data['B08006_013E_2010'])
commuting_data['B08006_014E_2010'] = pd.to_numeric(commuting_data['B08006_014E_2010'])
commuting_data['B08006_015E_2010'] = pd.to_numeric(commuting_data['B08006_015E_2010'])
commuting_data['B08006_016E_2010'] = pd.to_numeric(commuting_data['B08006_016E_2010'])
commuting_data['B08006_017E_2010'] = pd.to_numeric(commuting_data['B08006_017E_2010'])
commuting_data['B01001_001E_2011'] = pd.to_numeric(commuting_data['B01001_001E_2011'])
commuting_data['B08006_001E_2011'] = pd.to_numeric(commuting_data['B08006_001E_2011'])
commuting_data['B08006_002E_2011'] = pd.to_numeric(commuting_data['B08006_002E_2011'])
commuting_data['B08006_003E_2011'] = pd.to_numeric(commuting_data['B08006_003E_2011'])
commuting_data['B08006_004E_2011'] = pd.to_numeric(commuting_data['B08006_004E_2011'])
commuting_data['B08006_005E_2011'] = pd.to_numeric(commuting_data['B08006_005E_2011'])
commuting_data['B08006_006E_2011'] = pd.to_numeric(commuting_data['B08006_006E_2011'])
commuting_data['B08006_007E_2011'] = pd.to_numeric(commuting_data['B08006_007E_2011'])
commuting_data['B08006_008E_2011'] = pd.to_numeric(commuting_data['B08006_008E_2011'])
commuting_data['B08006_009E_2011'] = pd.to_numeric(commuting_data['B08006_009E_2011'])
commuting_data['B08006_010E_2011'] = pd.to_numeric(commuting_data['B08006_010E_2011'])
commuting_data['B08006_011E_2011'] = pd.to_numeric(commuting_data['B08006_011E_2011'])
commuting_data['B08006_012E_2011'] = pd.to_numeric(commuting_data['B08006_012E_2011'])
commuting_data['B08006_013E_2011'] = pd.to_numeric(commuting_data['B08006_013E_2011'])
commuting_data['B08006_014E_2011'] = pd.to_numeric(commuting_data['B08006_014E_2011'])
commuting_data['B08006_015E_2011'] = pd.to_numeric(commuting_data['B08006_015E_2011'])
commuting_data['B08006_016E_2011'] = pd.to_numeric(commuting_data['B08006_016E_2011'])
commuting_data['B08006_017E_2011'] = pd.to_numeric(commuting_data['B08006_017E_2011'])
commuting_data['B01001_001E_2012'] = pd.to_numeric(commuting_data['B01001_001E_2012'])
commuting_data['B08006_001E_2012'] = pd.to_numeric(commuting_data['B08006_001E_2012'])
commuting_data['B08006_002E_2012'] = pd.to_numeric(commuting_data['B08006_002E_2012'])
commuting_data['B08006_003E_2012'] = pd.to_numeric(commuting_data['B08006_003E_2012'])
commuting_data['B08006_004E_2012'] = pd.to_numeric(commuting_data['B08006_004E_2012'])
commuting_data['B08006_005E_2012'] = pd.to_numeric(commuting_data['B08006_005E_2012'])
commuting_data['B08006_006E_2012'] = pd.to_numeric(commuting_data['B08006_006E_2012'])
commuting_data['B08006_007E_2012'] = pd.to_numeric(commuting_data['B08006_007E_2012'])
commuting_data['B08006_008E_2012'] = pd.to_numeric(commuting_data['B08006_008E_2012'])
commuting_data['B08006_009E_2012'] = pd.to_numeric(commuting_data['B08006_009E_2012'])
commuting_data['B08006_010E_2012'] = pd.to_numeric(commuting_data['B08006_010E_2012'])
commuting_data['B08006_011E_2012'] = pd.to_numeric(commuting_data['B08006_011E_2012'])
commuting_data['B08006_012E_2012'] = pd.to_numeric(commuting_data['B08006_012E_2012'])
commuting_data['B08006_013E_2012'] = pd.to_numeric(commuting_data['B08006_013E_2012'])
commuting_data['B08006_014E_2012'] = pd.to_numeric(commuting_data['B08006_014E_2012'])
commuting_data['B08006_015E_2012'] = pd.to_numeric(commuting_data['B08006_015E_2012'])
commuting_data['B08006_016E_2012'] = pd.to_numeric(commuting_data['B08006_016E_2012'])
commuting_data['B08006_017E_2012'] = pd.to_numeric(commuting_data['B08006_017E_2012'])
commuting_data['B01001_001E_2013'] = pd.to_numeric(commuting_data['B01001_001E_2013'])
commuting_data['B08006_001E_2013'] = pd.to_numeric(commuting_data['B08006_001E_2013'])
commuting_data['B08006_002E_2013'] = pd.to_numeric(commuting_data['B08006_002E_2013'])
commuting_data['B08006_003E_2013'] = pd.to_numeric(commuting_data['B08006_003E_2013'])
commuting_data['B08006_004E_2013'] = pd.to_numeric(commuting_data['B08006_004E_2013'])
commuting_data['B08006_005E_2013'] = pd.to_numeric(commuting_data['B08006_005E_2013'])
commuting_data['B08006_006E_2013'] = pd.to_numeric(commuting_data['B08006_006E_2013'])
commuting_data['B08006_007E_2013'] = pd.to_numeric(commuting_data['B08006_007E_2013'])
commuting_data['B08006_008E_2013'] = pd.to_numeric(commuting_data['B08006_008E_2013'])
commuting_data['B08006_009E_2013'] = pd.to_numeric(commuting_data['B08006_009E_2013'])
commuting_data['B08006_010E_2013'] = pd.to_numeric(commuting_data['B08006_010E_2013'])
commuting_data['B08006_011E_2013'] = pd.to_numeric(commuting_data['B08006_011E_2013'])
commuting_data['B08006_012E_2013'] = pd.to_numeric(commuting_data['B08006_012E_2013'])
commuting_data['B08006_013E_2013'] = pd.to_numeric(commuting_data['B08006_013E_2013'])
commuting_data['B08006_014E_2013'] = pd.to_numeric(commuting_data['B08006_014E_2013'])
commuting_data['B08006_015E_2013'] = pd.to_numeric(commuting_data['B08006_015E_2013'])
commuting_data['B08006_016E_2013'] = pd.to_numeric(commuting_data['B08006_016E_2013'])
commuting_data['B08006_017E_2013'] = pd.to_numeric(commuting_data['B08006_017E_2013'])
commuting_data['B01001_001E_2014'] = pd.to_numeric(commuting_data['B01001_001E_2014'])
commuting_data['B08006_001E_2014'] = pd.to_numeric(commuting_data['B08006_001E_2014'])
commuting_data['B08006_002E_2014'] = pd.to_numeric(commuting_data['B08006_002E_2014'])
commuting_data['B08006_003E_2014'] = pd.to_numeric(commuting_data['B08006_003E_2014'])
commuting_data['B08006_004E_2014'] = pd.to_numeric(commuting_data['B08006_004E_2014'])
commuting_data['B08006_005E_2014'] = pd.to_numeric(commuting_data['B08006_005E_2014'])
commuting_data['B08006_006E_2014'] = pd.to_numeric(commuting_data['B08006_006E_2014'])
commuting_data['B08006_007E_2014'] = pd.to_numeric(commuting_data['B08006_007E_2014'])
commuting_data['B08006_008E_2014'] = pd.to_numeric(commuting_data['B08006_008E_2014'])
commuting_data['B08006_009E_2014'] = pd.to_numeric(commuting_data['B08006_009E_2014'])
commuting_data['B08006_010E_2014'] = pd.to_numeric(commuting_data['B08006_010E_2014'])
commuting_data['B08006_011E_2014'] = pd.to_numeric(commuting_data['B08006_011E_2014'])
commuting_data['B08006_012E_2014'] = pd.to_numeric(commuting_data['B08006_012E_2014'])
commuting_data['B08006_013E_2014'] = pd.to_numeric(commuting_data['B08006_013E_2014'])
commuting_data['B08006_014E_2014'] = pd.to_numeric(commuting_data['B08006_014E_2014'])
commuting_data['B08006_015E_2014'] = pd.to_numeric(commuting_data['B08006_015E_2014'])
commuting_data['B08006_016E_2014'] = pd.to_numeric(commuting_data['B08006_016E_2014'])
commuting_data['B08006_017E_2014'] = pd.to_numeric(commuting_data['B08006_017E_2014'])
commuting_data['B01001_001E_2015'] = pd.to_numeric(commuting_data['B01001_001E_2015'])
commuting_data['B08006_001E_2015'] = pd.to_numeric(commuting_data['B08006_001E_2015'])
commuting_data['B08006_002E_2015'] = pd.to_numeric(commuting_data['B08006_002E_2015'])
commuting_data['B08006_003E_2015'] = pd.to_numeric(commuting_data['B08006_003E_2015'])
commuting_data['B08006_004E_2015'] = pd.to_numeric(commuting_data['B08006_004E_2015'])
commuting_data['B08006_005E_2015'] = pd.to_numeric(commuting_data['B08006_005E_2015'])
commuting_data['B08006_006E_2015'] = pd.to_numeric(commuting_data['B08006_006E_2015'])
commuting_data['B08006_007E_2015'] = pd.to_numeric(commuting_data['B08006_007E_2015'])
commuting_data['B08006_008E_2015'] = pd.to_numeric(commuting_data['B08006_008E_2015'])
commuting_data['B08006_009E_2015'] = pd.to_numeric(commuting_data['B08006_009E_2015'])
commuting_data['B08006_010E_2015'] = pd.to_numeric(commuting_data['B08006_010E_2015'])
commuting_data['B08006_011E_2015'] = pd.to_numeric(commuting_data['B08006_011E_2015'])
commuting_data['B08006_012E_2015'] = pd.to_numeric(commuting_data['B08006_012E_2015'])
commuting_data['B08006_013E_2015'] = pd.to_numeric(commuting_data['B08006_013E_2015'])
commuting_data['B08006_014E_2015'] = pd.to_numeric(commuting_data['B08006_014E_2015'])
commuting_data['B08006_015E_2015'] = pd.to_numeric(commuting_data['B08006_015E_2015'])
commuting_data['B08006_016E_2015'] = pd.to_numeric(commuting_data['B08006_016E_2015'])
commuting_data['B08006_017E_2015'] = pd.to_numeric(commuting_data['B08006_017E_2015'])
commuting_data['B01001_001E_2016'] = pd.to_numeric(commuting_data['B01001_001E_2016'])
commuting_data['B08006_001E_2016'] = pd.to_numeric(commuting_data['B08006_001E_2016'])
commuting_data['B08006_002E_2016'] = pd.to_numeric(commuting_data['B08006_002E_2016'])
commuting_data['B08006_003E_2016'] = pd.to_numeric(commuting_data['B08006_003E_2016'])
commuting_data['B08006_004E_2016'] = pd.to_numeric(commuting_data['B08006_004E_2016'])
commuting_data['B08006_005E_2016'] = pd.to_numeric(commuting_data['B08006_005E_2016'])
commuting_data['B08006_006E_2016'] = pd.to_numeric(commuting_data['B08006_006E_2016'])
commuting_data['B08006_007E_2016'] = pd.to_numeric(commuting_data['B08006_007E_2016'])
commuting_data['B08006_008E_2016'] = pd.to_numeric(commuting_data['B08006_008E_2016'])
commuting_data['B08006_009E_2016'] = pd.to_numeric(commuting_data['B08006_009E_2016'])
commuting_data['B08006_010E_2016'] = pd.to_numeric(commuting_data['B08006_010E_2016'])
commuting_data['B08006_011E_2016'] = pd.to_numeric(commuting_data['B08006_011E_2016'])
commuting_data['B08006_012E_2016'] = pd.to_numeric(commuting_data['B08006_012E_2016'])
commuting_data['B08006_013E_2016'] = pd.to_numeric(commuting_data['B08006_013E_2016'])
commuting_data['B08006_014E_2016'] = pd.to_numeric(commuting_data['B08006_014E_2016'])
commuting_data['B08006_015E_2016'] = pd.to_numeric(commuting_data['B08006_015E_2016'])
commuting_data['B08006_016E_2016'] = pd.to_numeric(commuting_data['B08006_016E_2016'])
commuting_data['B08006_017E_2016'] = pd.to_numeric(commuting_data['B08006_017E_2016'])
commuting_data['B01001_001E_2017'] = pd.to_numeric(commuting_data['B01001_001E_2017'])
commuting_data['B08006_001E_2017'] = pd.to_numeric(commuting_data['B08006_001E_2017'])
commuting_data['B08006_002E_2017'] = pd.to_numeric(commuting_data['B08006_002E_2017'])
commuting_data['B08006_003E_2017'] = pd.to_numeric(commuting_data['B08006_003E_2017'])
commuting_data['B08006_004E_2017'] = pd.to_numeric(commuting_data['B08006_004E_2017'])
commuting_data['B08006_005E_2017'] = pd.to_numeric(commuting_data['B08006_005E_2017'])
commuting_data['B08006_006E_2017'] = pd.to_numeric(commuting_data['B08006_006E_2017'])
commuting_data['B08006_007E_2017'] = pd.to_numeric(commuting_data['B08006_007E_2017'])
commuting_data['B08006_008E_2017'] = pd.to_numeric(commuting_data['B08006_008E_2017'])
commuting_data['B08006_009E_2017'] = pd.to_numeric(commuting_data['B08006_009E_2017'])
commuting_data['B08006_010E_2017'] = pd.to_numeric(commuting_data['B08006_010E_2017'])
commuting_data['B08006_011E_2017'] = pd.to_numeric(commuting_data['B08006_011E_2017'])
commuting_data['B08006_012E_2017'] = pd.to_numeric(commuting_data['B08006_012E_2017'])
commuting_data['B08006_013E_2017'] = pd.to_numeric(commuting_data['B08006_013E_2017'])
commuting_data['B08006_014E_2017'] = pd.to_numeric(commuting_data['B08006_014E_2017'])
commuting_data['B08006_015E_2017'] = pd.to_numeric(commuting_data['B08006_015E_2017'])
commuting_data['B08006_016E_2017'] = pd.to_numeric(commuting_data['B08006_016E_2017'])
commuting_data['B08006_017E_2017'] = pd.to_numeric(commuting_data['B08006_017E_2017'])
commuting_data['B01001_001E_2018'] = pd.to_numeric(commuting_data['B01001_001E_2018'])
commuting_data['B08006_001E_2018'] = pd.to_numeric(commuting_data['B08006_001E_2018'])
commuting_data['B08006_002E_2018'] = pd.to_numeric(commuting_data['B08006_002E_2018'])
commuting_data['B08006_003E_2018'] = pd.to_numeric(commuting_data['B08006_003E_2018'])
commuting_data['B08006_004E_2018'] = pd.to_numeric(commuting_data['B08006_004E_2018'])
commuting_data['B08006_005E_2018'] = pd.to_numeric(commuting_data['B08006_005E_2018'])
commuting_data['B08006_006E_2018'] = pd.to_numeric(commuting_data['B08006_006E_2018'])
commuting_data['B08006_007E_2018'] = pd.to_numeric(commuting_data['B08006_007E_2018'])
commuting_data['B08006_008E_2018'] = pd.to_numeric(commuting_data['B08006_008E_2018'])
commuting_data['B08006_009E_2018'] = pd.to_numeric(commuting_data['B08006_009E_2018'])
commuting_data['B08006_010E_2018'] = pd.to_numeric(commuting_data['B08006_010E_2018'])
commuting_data['B08006_011E_2018'] = pd.to_numeric(commuting_data['B08006_011E_2018'])
commuting_data['B08006_012E_2018'] = pd.to_numeric(commuting_data['B08006_012E_2018'])
commuting_data['B08006_013E_2018'] = pd.to_numeric(commuting_data['B08006_013E_2018'])
commuting_data['B08006_014E_2018'] = pd.to_numeric(commuting_data['B08006_014E_2018'])
commuting_data['B08006_015E_2018'] = pd.to_numeric(commuting_data['B08006_015E_2018'])
commuting_data['B08006_016E_2018'] = pd.to_numeric(commuting_data['B08006_016E_2018'])
commuting_data['B08006_017E_2018'] = pd.to_numeric(commuting_data['B08006_017E_2018'])
commuting_data['B01001_001E_2019'] = pd.to_numeric(commuting_data['B01001_001E_2019'])
commuting_data['B08006_001E_2019'] = pd.to_numeric(commuting_data['B08006_001E_2019'])
commuting_data['B08006_002E_2019'] = pd.to_numeric(commuting_data['B08006_002E_2019'])
commuting_data['B08006_003E_2019'] = pd.to_numeric(commuting_data['B08006_003E_2019'])
commuting_data['B08006_004E_2019'] = pd.to_numeric(commuting_data['B08006_004E_2019'])
commuting_data['B08006_005E_2019'] = pd.to_numeric(commuting_data['B08006_005E_2019'])
commuting_data['B08006_006E_2019'] = pd.to_numeric(commuting_data['B08006_006E_2019'])
commuting_data['B08006_007E_2019'] = pd.to_numeric(commuting_data['B08006_007E_2019'])
commuting_data['B08006_008E_2019'] = pd.to_numeric(commuting_data['B08006_008E_2019'])
commuting_data['B08006_009E_2019'] = pd.to_numeric(commuting_data['B08006_009E_2019'])
commuting_data['B08006_010E_2019'] = pd.to_numeric(commuting_data['B08006_010E_2019'])
commuting_data['B08006_011E_2019'] = pd.to_numeric(commuting_data['B08006_011E_2019'])
commuting_data['B08006_012E_2019'] = pd.to_numeric(commuting_data['B08006_012E_2019'])
commuting_data['B08006_013E_2019'] = pd.to_numeric(commuting_data['B08006_013E_2019'])
commuting_data['B08006_014E_2019'] = pd.to_numeric(commuting_data['B08006_014E_2019'])
commuting_data['B08006_015E_2019'] = pd.to_numeric(commuting_data['B08006_015E_2019'])
commuting_data['B08006_016E_2019'] = pd.to_numeric(commuting_data['B08006_016E_2019'])
commuting_data['B08006_017E_2019'] = pd.to_numeric(commuting_data['B08006_017E_2019'])
commuting_data['B01001_001E_2020'] = pd.to_numeric(commuting_data['B01001_001E_2020'])
commuting_data['B08006_001E_2020'] = pd.to_numeric(commuting_data['B08006_001E_2020'])
commuting_data['B08006_002E_2020'] = pd.to_numeric(commuting_data['B08006_002E_2020'])
commuting_data['B08006_003E_2020'] = pd.to_numeric(commuting_data['B08006_003E_2020'])
commuting_data['B08006_004E_2020'] = pd.to_numeric(commuting_data['B08006_004E_2020'])
commuting_data['B08006_005E_2020'] = pd.to_numeric(commuting_data['B08006_005E_2020'])
commuting_data['B08006_006E_2020'] = pd.to_numeric(commuting_data['B08006_006E_2020'])
commuting_data['B08006_007E_2020'] = pd.to_numeric(commuting_data['B08006_007E_2020'])
commuting_data['B08006_008E_2020'] = pd.to_numeric(commuting_data['B08006_008E_2020'])
commuting_data['B08006_009E_2020'] = pd.to_numeric(commuting_data['B08006_009E_2020'])
commuting_data['B08006_010E_2020'] = pd.to_numeric(commuting_data['B08006_010E_2020'])
commuting_data['B08006_011E_2020'] = pd.to_numeric(commuting_data['B08006_011E_2020'])
commuting_data['B08006_012E_2020'] = pd.to_numeric(commuting_data['B08006_012E_2020'])
commuting_data['B08006_013E_2020'] = pd.to_numeric(commuting_data['B08006_013E_2020'])
commuting_data['B08006_014E_2020'] = pd.to_numeric(commuting_data['B08006_014E_2020'])
commuting_data['B08006_015E_2020'] = pd.to_numeric(commuting_data['B08006_015E_2020'])
commuting_data['B08006_016E_2020'] = pd.to_numeric(commuting_data['B08006_016E_2020'])
commuting_data['B08006_017E_2020'] = pd.to_numeric(commuting_data['B08006_017E_2020'])
commuting_data['B01001_001E_2021'] = pd.to_numeric(commuting_data['B01001_001E_2021'])
commuting_data['B08006_001E_2021'] = pd.to_numeric(commuting_data['B08006_001E_2021'])
commuting_data['B08006_002E_2021'] = pd.to_numeric(commuting_data['B08006_002E_2021'])
commuting_data['B08006_003E_2021'] = pd.to_numeric(commuting_data['B08006_003E_2021'])
commuting_data['B08006_004E_2021'] = pd.to_numeric(commuting_data['B08006_004E_2021'])
commuting_data['B08006_005E_2021'] = pd.to_numeric(commuting_data['B08006_005E_2021'])
commuting_data['B08006_006E_2021'] = pd.to_numeric(commuting_data['B08006_006E_2021'])
commuting_data['B08006_007E_2021'] = pd.to_numeric(commuting_data['B08006_007E_2021'])
commuting_data['B08006_008E_2021'] = pd.to_numeric(commuting_data['B08006_008E_2021'])
commuting_data['B08006_009E_2021'] = pd.to_numeric(commuting_data['B08006_009E_2021'])
commuting_data['B08006_010E_2021'] = pd.to_numeric(commuting_data['B08006_010E_2021'])
commuting_data['B08006_011E_2021'] = pd.to_numeric(commuting_data['B08006_011E_2021'])
commuting_data['B08006_012E_2021'] = pd.to_numeric(commuting_data['B08006_012E_2021'])
commuting_data['B08006_013E_2021'] = pd.to_numeric(commuting_data['B08006_013E_2021'])
commuting_data['B08006_014E_2021'] = pd.to_numeric(commuting_data['B08006_014E_2021'])
commuting_data['B08006_015E_2021'] = pd.to_numeric(commuting_data['B08006_015E_2021'])
commuting_data['B08006_016E_2021'] = pd.to_numeric(commuting_data['B08006_016E_2021'])
commuting_data['B08006_017E_2021'] = pd.to_numeric(commuting_data['B08006_017E_2021'])

# %%
commuting_data=commuting_data.fillna(0)

# %%
# For each year
# need \

# TOTAL ACTIVE TRANSPORATATION B08006_008E + B08006_014E, + B08006_015E
# PERCENT ACTIVE TRANSPORATION B08006_008E + B08006_014E, + B08006_015E / B08006_001E

# already have 

# TOTAL COMMUTERS
# TOTAL POPULATION

# FIELDS across years
# Change in number of active commuters 2010-2021
# chamge in number of active commuters per capita 2010-2021

# %%
for year in years:
    print(f"commuting_data['total_active_commuters_{year}']=0")
    print(f"commuting_data['percent_of_commuters_active_{year}']=0.0")
    print(f"commuting_data['percent_of_non_wfh_commuters_active_{year}']=0.0")
    print(f"commuting_data['total_cyclists_{year}']=0")
    print(f"commuting_data['bike_share_{year}']=0.0")
    print(f"commuting_data['non_wfh_bike_share_{year}']=0.0")
    # todo add cyclists here

for year in years:
    print(f"commuting_data['total_active_commuters_{year}'][x] = int(commuting_data['B08006_008E_{year}'][x]) + int(commuting_data['B08006_014E_{year}'][x]) + int(commuting_data['B08006_015E_{year}'][x])")
    print(f"commuting_data['percent_of_commuters_active_{year}'][x] = (int(commuting_data['B08006_008E_{year}'][x]) + int(commuting_data['B08006_014E_{year}'][x]) + int(commuting_data['B08006_015E_{year}'][x])) / int(commuting_data['B08006_001E_{year}'][x])")
    print(f"commuting_data['percent_of_non_wfh_commuters_active_{year}'][x] = (int(commuting_data['B08006_008E_{year}'][x]) + int(commuting_data['B08006_014E_{year}'][x]) + int(commuting_data['B08006_015E_{year}'][x])) / (int(commuting_data['B08006_001E_{year}'][x])-int(commuting_data['B08006_017E_{year}'][x]))")

    print(f"commuting_data['total_cyclists_{year}'][x] = int(commuting_data['B08006_014E_{year}'][x])")
    print(f"commuting_data['bike_share_{year}'][x] = (int(commuting_data['B08006_014E_{year}'][x])) / int(commuting_data['B08006_001E_{year}'][x])")
    print(f"commuting_data['non_wfh_bike_share_{year}'][x] = (int(commuting_data['B08006_014E_{year}'][x])) / (int(commuting_data['B08006_001E_{year}'][x])-int(commuting_data['B08006_017E_{year}'][x]))")
# Out:
# commuting_data['total_active_commuters_2010']=0
# commuting_data['percent_of_commuters_active_2010']=0.0
# commuting_data['percent_of_non_wfh_commuters_active_2010']=0.0
# commuting_data['total_cyclists_2010']=0
# commuting_data['bike_share_2010']=0.0
# commuting_data['non_wfh_bike_share_2010']=0.0
# commuting_data['total_active_commuters_2011']=0
# commuting_data['percent_of_commuters_active_2011']=0.0
# commuting_data['percent_of_non_wfh_commuters_active_2011']=0.0
# commuting_data['total_cyclists_2011']=0
# commuting_data['bike_share_2011']=0.0
# commuting_data['non_wfh_bike_share_2011']=0.0
# commuting_data['total_active_commuters_2012']=0
# commuting_data['percent_of_commuters_active_2012']=0.0
# commuting_data['percent_of_non_wfh_commuters_active_2012']=0.0
# commuting_data['total_cyclists_2012']=0
# commuting_data['bike_share_2012']=0.0
# commuting_data['non_wfh_bike_share_2012']=0.0
# commuting_data['total_active_commuters_2013']=0
# ...

# %%
commuting_data['total_active_commuters_2010']=0
commuting_data['percent_of_commuters_active_2010']=0.0
commuting_data['percent_of_non_wfh_commuters_active_2010']=0.0
commuting_data['total_cyclists_2010']=0
commuting_data['bike_share_2010']=0.0
commuting_data['non_wfh_bike_share_2010']=0.0
commuting_data['total_active_commuters_2011']=0
commuting_data['percent_of_commuters_active_2011']=0.0
commuting_data['percent_of_non_wfh_commuters_active_2011']=0.0
commuting_data['total_cyclists_2011']=0
commuting_data['bike_share_2011']=0.0
commuting_data['non_wfh_bike_share_2011']=0.0
commuting_data['total_active_commuters_2012']=0
commuting_data['percent_of_commuters_active_2012']=0.0
commuting_data['percent_of_non_wfh_commuters_active_2012']=0.0
commuting_data['total_cyclists_2012']=0
commuting_data['bike_share_2012']=0.0
commuting_data['non_wfh_bike_share_2012']=0.0
commuting_data['total_active_commuters_2013']=0
commuting_data['percent_of_commuters_active_2013']=0.0
commuting_data['percent_of_non_wfh_commuters_active_2013']=0.0
commuting_data['total_cyclists_2013']=0
commuting_data['bike_share_2013']=0.0
commuting_data['non_wfh_bike_share_2013']=0.0
commuting_data['total_active_commuters_2014']=0
commuting_data['percent_of_commuters_active_2014']=0.0
commuting_data['percent_of_non_wfh_commuters_active_2014']=0.0
commuting_data['total_cyclists_2014']=0
commuting_data['bike_share_2014']=0.0
commuting_data['non_wfh_bike_share_2014']=0.0
commuting_data['total_active_commuters_2015']=0
commuting_data['percent_of_commuters_active_2015']=0.0
commuting_data['percent_of_non_wfh_commuters_active_2015']=0.0
commuting_data['total_cyclists_2015']=0
commuting_data['bike_share_2015']=0.0
commuting_data['non_wfh_bike_share_2015']=0.0
commuting_data['total_active_commuters_2016']=0
commuting_data['percent_of_commuters_active_2016']=0.0
commuting_data['percent_of_non_wfh_commuters_active_2016']=0.0
commuting_data['total_cyclists_2016']=0
commuting_data['bike_share_2016']=0.0
commuting_data['non_wfh_bike_share_2016']=0.0
commuting_data['total_active_commuters_2017']=0
commuting_data['percent_of_commuters_active_2017']=0.0
commuting_data['percent_of_non_wfh_commuters_active_2017']=0.0
commuting_data['total_cyclists_2017']=0
commuting_data['bike_share_2017']=0.0
commuting_data['non_wfh_bike_share_2017']=0.0
commuting_data['total_active_commuters_2018']=0
commuting_data['percent_of_commuters_active_2018']=0.0
commuting_data['percent_of_non_wfh_commuters_active_2018']=0.0
commuting_data['total_cyclists_2018']=0
commuting_data['bike_share_2018']=0.0
commuting_data['non_wfh_bike_share_2018']=0.0
commuting_data['total_active_commuters_2019']=0
commuting_data['percent_of_commuters_active_2019']=0.0
commuting_data['percent_of_non_wfh_commuters_active_2019']=0.0
commuting_data['total_cyclists_2019']=0
commuting_data['bike_share_2019']=0.0
commuting_data['non_wfh_bike_share_2019']=0.0
commuting_data['total_active_commuters_2020']=0
commuting_data['percent_of_commuters_active_2020']=0.0
commuting_data['percent_of_non_wfh_commuters_active_2020']=0.0
commuting_data['total_cyclists_2020']=0
commuting_data['bike_share_2020']=0.0
commuting_data['non_wfh_bike_share_2020']=0.0
commuting_data['total_active_commuters_2021']=0
commuting_data['percent_of_commuters_active_2021']=0.0
commuting_data['percent_of_non_wfh_commuters_active_2021']=0.0
commuting_data['total_cyclists_2021']=0
commuting_data['bike_share_2021']=0.0
commuting_data['non_wfh_bike_share_2021']=0.0

# %%
#  fix null value breaking the code
commuting_data['B08006_001E_2018']['21580']=1

for x in commuting_data.index:
    commuting_data['total_active_commuters_2010'][x] = int(commuting_data['B08006_008E_2010'][x]) + int(commuting_data['B08006_014E_2010'][x]) + int(commuting_data['B08006_015E_2010'][x])
    commuting_data['percent_of_commuters_active_2010'][x] = (int(commuting_data['B08006_008E_2010'][x]) + int(commuting_data['B08006_014E_2010'][x]) + int(commuting_data['B08006_015E_2010'][x])) / int(commuting_data['B08006_001E_2010'][x])
    commuting_data['percent_of_non_wfh_commuters_active_2010'][x] = (int(commuting_data['B08006_008E_2010'][x]) + int(commuting_data['B08006_014E_2010'][x]) + int(commuting_data['B08006_015E_2010'][x])) / (int(commuting_data['B08006_001E_2010'][x])-int(commuting_data['B08006_017E_2010'][x]))
    commuting_data['total_cyclists_2010'][x] = int(commuting_data['B08006_014E_2010'][x])
    commuting_data['bike_share_2010'][x] = (int(commuting_data['B08006_014E_2010'][x])) / int(commuting_data['B08006_001E_2010'][x])
    commuting_data['non_wfh_bike_share_2010'][x] = (int(commuting_data['B08006_014E_2010'][x])) / (int(commuting_data['B08006_001E_2010'][x])-int(commuting_data['B08006_017E_2010'][x]))
    commuting_data['total_active_commuters_2011'][x] = int(commuting_data['B08006_008E_2011'][x]) + int(commuting_data['B08006_014E_2011'][x]) + int(commuting_data['B08006_015E_2011'][x])
    commuting_data['percent_of_commuters_active_2011'][x] = (int(commuting_data['B08006_008E_2011'][x]) + int(commuting_data['B08006_014E_2011'][x]) + int(commuting_data['B08006_015E_2011'][x])) / int(commuting_data['B08006_001E_2011'][x])
    commuting_data['percent_of_non_wfh_commuters_active_2011'][x] = (int(commuting_data['B08006_008E_2011'][x]) + int(commuting_data['B08006_014E_2011'][x]) + int(commuting_data['B08006_015E_2011'][x])) / (int(commuting_data['B08006_001E_2011'][x])-int(commuting_data['B08006_017E_2011'][x]))
    commuting_data['total_cyclists_2011'][x] = int(commuting_data['B08006_014E_2011'][x])
    commuting_data['bike_share_2011'][x] = (int(commuting_data['B08006_014E_2011'][x])) / int(commuting_data['B08006_001E_2011'][x])
    commuting_data['non_wfh_bike_share_2011'][x] = (int(commuting_data['B08006_014E_2011'][x])) / (int(commuting_data['B08006_001E_2011'][x])-int(commuting_data['B08006_017E_2011'][x]))
    commuting_data['total_active_commuters_2012'][x] = int(commuting_data['B08006_008E_2012'][x]) + int(commuting_data['B08006_014E_2012'][x]) + int(commuting_data['B08006_015E_2012'][x])
    commuting_data['percent_of_commuters_active_2012'][x] = (int(commuting_data['B08006_008E_2012'][x]) + int(commuting_data['B08006_014E_2012'][x]) + int(commuting_data['B08006_015E_2012'][x])) / int(commuting_data['B08006_001E_2012'][x])
    commuting_data['percent_of_non_wfh_commuters_active_2012'][x] = (int(commuting_data['B08006_008E_2012'][x]) + int(commuting_data['B08006_014E_2012'][x]) + int(commuting_data['B08006_015E_2012'][x])) / (int(commuting_data['B08006_001E_2012'][x])-int(commuting_data['B08006_017E_2012'][x]))
    commuting_data['total_cyclists_2012'][x] = int(commuting_data['B08006_014E_2012'][x])
    commuting_data['bike_share_2012'][x] = (int(commuting_data['B08006_014E_2012'][x])) / int(commuting_data['B08006_001E_2012'][x])
    commuting_data['non_wfh_bike_share_2012'][x] = (int(commuting_data['B08006_014E_2012'][x])) / (int(commuting_data['B08006_001E_2012'][x])-int(commuting_data['B08006_017E_2012'][x]))
    commuting_data['total_active_commuters_2013'][x] = int(commuting_data['B08006_008E_2013'][x]) + int(commuting_data['B08006_014E_2013'][x]) + int(commuting_data['B08006_015E_2013'][x])
    commuting_data['percent_of_commuters_active_2013'][x] = (int(commuting_data['B08006_008E_2013'][x]) + int(commuting_data['B08006_014E_2013'][x]) + int(commuting_data['B08006_015E_2013'][x])) / int(commuting_data['B08006_001E_2013'][x])
    commuting_data['percent_of_non_wfh_commuters_active_2013'][x] = (int(commuting_data['B08006_008E_2013'][x]) + int(commuting_data['B08006_014E_2013'][x]) + int(commuting_data['B08006_015E_2013'][x])) / (int(commuting_data['B08006_001E_2013'][x])-int(commuting_data['B08006_017E_2013'][x]))
    commuting_data['total_cyclists_2013'][x] = int(commuting_data['B08006_014E_2013'][x])
    commuting_data['bike_share_2013'][x] = (int(commuting_data['B08006_014E_2013'][x])) / int(commuting_data['B08006_001E_2013'][x])
    commuting_data['non_wfh_bike_share_2013'][x] = (int(commuting_data['B08006_014E_2013'][x])) / (int(commuting_data['B08006_001E_2013'][x])-int(commuting_data['B08006_017E_2013'][x]))
    commuting_data['total_active_commuters_2014'][x] = int(commuting_data['B08006_008E_2014'][x]) + int(commuting_data['B08006_014E_2014'][x]) + int(commuting_data['B08006_015E_2014'][x])
    commuting_data['percent_of_commuters_active_2014'][x] = (int(commuting_data['B08006_008E_2014'][x]) + int(commuting_data['B08006_014E_2014'][x]) + int(commuting_data['B08006_015E_2014'][x])) / int(commuting_data['B08006_001E_2014'][x])
    commuting_data['percent_of_non_wfh_commuters_active_2014'][x] = (int(commuting_data['B08006_008E_2014'][x]) + int(commuting_data['B08006_014E_2014'][x]) + int(commuting_data['B08006_015E_2014'][x])) / (int(commuting_data['B08006_001E_2014'][x])-int(commuting_data['B08006_017E_2014'][x]))
    commuting_data['total_cyclists_2014'][x] = int(commuting_data['B08006_014E_2014'][x])
    commuting_data['bike_share_2014'][x] = (int(commuting_data['B08006_014E_2014'][x])) / int(commuting_data['B08006_001E_2014'][x])
    commuting_data['non_wfh_bike_share_2014'][x] = (int(commuting_data['B08006_014E_2014'][x])) / (int(commuting_data['B08006_001E_2014'][x])-int(commuting_data['B08006_017E_2014'][x]))
    commuting_data['total_active_commuters_2015'][x] = int(commuting_data['B08006_008E_2015'][x]) + int(commuting_data['B08006_014E_2015'][x]) + int(commuting_data['B08006_015E_2015'][x])
    commuting_data['percent_of_commuters_active_2015'][x] = (int(commuting_data['B08006_008E_2015'][x]) + int(commuting_data['B08006_014E_2015'][x]) + int(commuting_data['B08006_015E_2015'][x])) / int(commuting_data['B08006_001E_2015'][x])
    commuting_data['percent_of_non_wfh_commuters_active_2015'][x] = (int(commuting_data['B08006_008E_2015'][x]) + int(commuting_data['B08006_014E_2015'][x]) + int(commuting_data['B08006_015E_2015'][x])) / (int(commuting_data['B08006_001E_2015'][x])-int(commuting_data['B08006_017E_2015'][x]))
    commuting_data['total_cyclists_2015'][x] = int(commuting_data['B08006_014E_2015'][x])
    commuting_data['bike_share_2015'][x] = (int(commuting_data['B08006_014E_2015'][x])) / int(commuting_data['B08006_001E_2015'][x])
    commuting_data['non_wfh_bike_share_2015'][x] = (int(commuting_data['B08006_014E_2015'][x])) / (int(commuting_data['B08006_001E_2015'][x])-int(commuting_data['B08006_017E_2015'][x]))
    commuting_data['total_active_commuters_2016'][x] = int(commuting_data['B08006_008E_2016'][x]) + int(commuting_data['B08006_014E_2016'][x]) + int(commuting_data['B08006_015E_2016'][x])
    commuting_data['percent_of_commuters_active_2016'][x] = (int(commuting_data['B08006_008E_2016'][x]) + int(commuting_data['B08006_014E_2016'][x]) + int(commuting_data['B08006_015E_2016'][x])) / int(commuting_data['B08006_001E_2016'][x])
    commuting_data['percent_of_non_wfh_commuters_active_2016'][x] = (int(commuting_data['B08006_008E_2016'][x]) + int(commuting_data['B08006_014E_2016'][x]) + int(commuting_data['B08006_015E_2016'][x])) / (int(commuting_data['B08006_001E_2016'][x])-int(commuting_data['B08006_017E_2016'][x]))
    commuting_data['total_cyclists_2016'][x] = int(commuting_data['B08006_014E_2016'][x])
    commuting_data['bike_share_2016'][x] = (int(commuting_data['B08006_014E_2016'][x])) / int(commuting_data['B08006_001E_2016'][x])
    commuting_data['non_wfh_bike_share_2016'][x] = (int(commuting_data['B08006_014E_2016'][x])) / (int(commuting_data['B08006_001E_2016'][x])-int(commuting_data['B08006_017E_2016'][x]))
    commuting_data['total_active_commuters_2017'][x] = int(commuting_data['B08006_008E_2017'][x]) + int(commuting_data['B08006_014E_2017'][x]) + int(commuting_data['B08006_015E_2017'][x])
    commuting_data['percent_of_commuters_active_2017'][x] = (int(commuting_data['B08006_008E_2017'][x]) + int(commuting_data['B08006_014E_2017'][x]) + int(commuting_data['B08006_015E_2017'][x])) / int(commuting_data['B08006_001E_2017'][x])
    commuting_data['percent_of_non_wfh_commuters_active_2017'][x] = (int(commuting_data['B08006_008E_2017'][x]) + int(commuting_data['B08006_014E_2017'][x]) + int(commuting_data['B08006_015E_2017'][x])) / (int(commuting_data['B08006_001E_2017'][x])-int(commuting_data['B08006_017E_2017'][x]))
    commuting_data['total_cyclists_2017'][x] = int(commuting_data['B08006_014E_2017'][x])
    commuting_data['bike_share_2017'][x] = (int(commuting_data['B08006_014E_2017'][x])) / int(commuting_data['B08006_001E_2017'][x])
    commuting_data['non_wfh_bike_share_2017'][x] = (int(commuting_data['B08006_014E_2017'][x])) / (int(commuting_data['B08006_001E_2017'][x])-int(commuting_data['B08006_017E_2017'][x]))
    commuting_data['total_active_commuters_2018'][x] = int(commuting_data['B08006_008E_2018'][x]) + int(commuting_data['B08006_014E_2018'][x]) + int(commuting_data['B08006_015E_2018'][x])
    commuting_data['percent_of_commuters_active_2018'][x] = (int(commuting_data['B08006_008E_2018'][x]) + int(commuting_data['B08006_014E_2018'][x]) + int(commuting_data['B08006_015E_2018'][x])) / int(commuting_data['B08006_001E_2018'][x])
    commuting_data['percent_of_non_wfh_commuters_active_2018'][x] = (int(commuting_data['B08006_008E_2018'][x]) + int(commuting_data['B08006_014E_2018'][x]) + int(commuting_data['B08006_015E_2018'][x])) / (int(commuting_data['B08006_001E_2018'][x])-int(commuting_data['B08006_017E_2018'][x]))
    commuting_data['total_cyclists_2018'][x] = int(commuting_data['B08006_014E_2018'][x])
    commuting_data['bike_share_2018'][x] = (int(commuting_data['B08006_014E_2018'][x])) / int(commuting_data['B08006_001E_2018'][x])
    commuting_data['non_wfh_bike_share_2018'][x] = (int(commuting_data['B08006_014E_2018'][x])) / (int(commuting_data['B08006_001E_2018'][x])-int(commuting_data['B08006_017E_2018'][x]))
    commuting_data['total_active_commuters_2019'][x] = int(commuting_data['B08006_008E_2019'][x]) + int(commuting_data['B08006_014E_2019'][x]) + int(commuting_data['B08006_015E_2019'][x])
    commuting_data['percent_of_commuters_active_2019'][x] = (int(commuting_data['B08006_008E_2019'][x]) + int(commuting_data['B08006_014E_2019'][x]) + int(commuting_data['B08006_015E_2019'][x])) / int(commuting_data['B08006_001E_2019'][x])
    commuting_data['percent_of_non_wfh_commuters_active_2019'][x] = (int(commuting_data['B08006_008E_2019'][x]) + int(commuting_data['B08006_014E_2019'][x]) + int(commuting_data['B08006_015E_2019'][x])) / (int(commuting_data['B08006_001E_2019'][x])-int(commuting_data['B08006_017E_2019'][x]))
    commuting_data['total_cyclists_2019'][x] = int(commuting_data['B08006_014E_2019'][x])
    commuting_data['bike_share_2019'][x] = (int(commuting_data['B08006_014E_2019'][x])) / int(commuting_data['B08006_001E_2019'][x])
    commuting_data['non_wfh_bike_share_2019'][x] = (int(commuting_data['B08006_014E_2019'][x])) / (int(commuting_data['B08006_001E_2019'][x])-int(commuting_data['B08006_017E_2019'][x]))
    commuting_data['total_active_commuters_2020'][x] = int(commuting_data['B08006_008E_2020'][x]) + int(commuting_data['B08006_014E_2020'][x]) + int(commuting_data['B08006_015E_2020'][x])
    commuting_data['percent_of_commuters_active_2020'][x] = (int(commuting_data['B08006_008E_2020'][x]) + int(commuting_data['B08006_014E_2020'][x]) + int(commuting_data['B08006_015E_2020'][x])) / int(commuting_data['B08006_001E_2020'][x])
    commuting_data['percent_of_non_wfh_commuters_active_2020'][x] = (int(commuting_data['B08006_008E_2020'][x]) + int(commuting_data['B08006_014E_2020'][x]) + int(commuting_data['B08006_015E_2020'][x])) / (int(commuting_data['B08006_001E_2020'][x])-int(commuting_data['B08006_017E_2020'][x]))
    commuting_data['total_cyclists_2020'][x] = int(commuting_data['B08006_014E_2020'][x])
    commuting_data['bike_share_2020'][x] = (int(commuting_data['B08006_014E_2020'][x])) / int(commuting_data['B08006_001E_2020'][x])
    commuting_data['non_wfh_bike_share_2020'][x] = (int(commuting_data['B08006_014E_2020'][x])) / (int(commuting_data['B08006_001E_2020'][x])-int(commuting_data['B08006_017E_2020'][x]))
    commuting_data['total_active_commuters_2021'][x] = int(commuting_data['B08006_008E_2021'][x]) + int(commuting_data['B08006_014E_2021'][x]) + int(commuting_data['B08006_015E_2021'][x])
    commuting_data['percent_of_commuters_active_2021'][x] = (int(commuting_data['B08006_008E_2021'][x]) + int(commuting_data['B08006_014E_2021'][x]) + int(commuting_data['B08006_015E_2021'][x])) / int(commuting_data['B08006_001E_2021'][x])
    commuting_data['percent_of_non_wfh_commuters_active_2021'][x] = (int(commuting_data['B08006_008E_2021'][x]) + int(commuting_data['B08006_014E_2021'][x]) + int(commuting_data['B08006_015E_2021'][x])) / (int(commuting_data['B08006_001E_2021'][x])-int(commuting_data['B08006_017E_2021'][x]))
    commuting_data['total_cyclists_2021'][x] = int(commuting_data['B08006_014E_2021'][x])
    commuting_data['bike_share_2021'][x] = (int(commuting_data['B08006_014E_2021'][x])) / int(commuting_data['B08006_001E_2021'][x])
    commuting_data['non_wfh_bike_share_2021'][x] = (int(commuting_data['B08006_014E_2021'][x])) / (int(commuting_data['B08006_001E_2021'][x])-int(commuting_data['B08006_017E_2021'][x]))

    
commuting_data['change_in_active_commuters'] = commuting_data['total_active_commuters_2021'] - commuting_data['total_active_commuters_2010']
commuting_data['percent_change_in_active_commuters'] = (commuting_data['total_active_commuters_2021'] - commuting_data['total_active_commuters_2010'])/commuting_data['total_active_commuters_2010']
commuting_data['change_in_active_modeshare'] = commuting_data['percent_of_commuters_active_2021'] - commuting_data['percent_of_commuters_active_2010']
commuting_data['change_in_non_wfh_active_modeshare'] = commuting_data['percent_of_non_wfh_commuters_active_2021'] - commuting_data['percent_of_non_wfh_commuters_active_2010']
commuting_data['change_in_cyclists'] = commuting_data['total_cyclists_2021'] - commuting_data['total_cyclists_2010']
commuting_data['percent_change_in_cyclists'] = (commuting_data['total_cyclists_2021'] - commuting_data['total_cyclists_2010'])/commuting_data['total_cyclists_2010']
commuting_data['change_in_bike_share'] = commuting_data['bike_share_2021'] - commuting_data['bike_share_2010']
commuting_data['change_in_non_wfh_bike_share'] = commuting_data['non_wfh_bike_share_2021'] - commuting_data['non_wfh_bike_share_2010']
# Out:
# /tmp/ipykernel_70256/1966467774.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   commuting_data['B08006_001E_2018']['21580']=1
# /tmp/ipykernel_70256/1966467774.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   commuting_data['total_active_commuters_2010'][x] = int(commuting_data['B08006_008E_2010'][x]) + int(commuting_data['B08006_014E_2010'][x]) + int(commuting_data['B08006_015E_2010'][x])
# /tmp/ipykernel_70256/1966467774.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
commuting_data.to_csv("commuting_data.csv")

# %%
['change_in_active_commuters',
'percent_change_in_active_commuters',
'change_in_active_modeshare',
'change_in_non_wfh_active_modeshare',
'change_in_cyclists',
'percent_change_in_cyclists',
'change_in_bike_share',
'change_in_non_wfh_bike_share',
'metropolitan/micropolitan statistical area',
'total_active_commuters_2010',
'total_active_commuters_2011',
'total_active_commuters_2012',
'total_active_commuters_2013',
'total_active_commuters_2014',
'total_active_commuters_2015',
'total_active_commuters_2016',
'total_active_commuters_2017',
'total_active_commuters_2018',
'total_active_commuters_2019',
'total_active_commuters_2020',
'total_active_commuters_2021',
'total_cyclists_2010',
'total_cyclists_2011',
'total_cyclists_2012',
'total_cyclists_2013',
'total_cyclists_2014',
'total_cyclists_2015',
'total_cyclists_2016',
'total_cyclists_2017',
'total_cyclists_2018',
'total_cyclists_2019',
'total_cyclists_2020',
'total_cyclists_2021',
'percent_of_commuters_active_2010',
'percent_of_commuters_active_2011',
'percent_of_commuters_active_2012',
'percent_of_commuters_active_2013',
'percent_of_commuters_active_2014',
'percent_of_commuters_active_2015',
'percent_of_commuters_active_2016',
'percent_of_commuters_active_2017',
'percent_of_commuters_active_2018',
'percent_of_commuters_active_2019',
'percent_of_commuters_active_2020',
'percent_of_commuters_active_2021',
'bike_share_2010',
'bike_share_2011',
'bike_share_2012',
'bike_share_2013',
'bike_share_2014',
'bike_share_2015',
'bike_share_2016',
'bike_share_2017',
'bike_share_2018',
'bike_share_2019',
'bike_share_2020',
'bike_share_2021',
'percent_of_non_wfh_commuters_active_2010',
'percent_of_non_wfh_commuters_active_2011',
'percent_of_non_wfh_commuters_active_2012',
'percent_of_non_wfh_commuters_active_2013',
'percent_of_non_wfh_commuters_active_2014',
'percent_of_non_wfh_commuters_active_2015',
'percent_of_non_wfh_commuters_active_2016',
'percent_of_non_wfh_commuters_active_2017',
'percent_of_non_wfh_commuters_active_2018',
'percent_of_non_wfh_commuters_active_2019',
'percent_of_non_wfh_commuters_active_2020',
'percent_of_non_wfh_commuters_active_2021',
'non_wfh_bike_share_2010',
'non_wfh_bike_share_2011',
'non_wfh_bike_share_2012',
'non_wfh_bike_share_2013',
'non_wfh_bike_share_2014',
'non_wfh_bike_share_2015',
'non_wfh_bike_share_2016',
'non_wfh_bike_share_2017',
'non_wfh_bike_share_2018',
'non_wfh_bike_share_2019',
'non_wfh_bike_share_2020',
'non_wfh_bike_share_2021'
]
# Out:
# ['change_in_active_commuters',
#  'percent_change_in_active_commuters',
#  'change_in_active_modeshare',
#  'change_in_non_wfh_active_modeshare',
#  'change_in_cyclists',
#  'percent_change_in_cyclists',
#  'change_in_bike_share',
#  'change_in_non_wfh_bike_share',
#  'metropolitan/micropolitan statistical area',
#  'total_active_commuters_2010',
#  'total_active_commuters_2011',
#  'total_active_commuters_2012',
#  'total_active_commuters_2013',
#  'total_active_commuters_2014',
#  'total_active_commuters_2015',
#  'total_active_commuters_2016',
#  'total_active_commuters_2017',
#  'total_active_commuters_2018',
#  'total_active_commuters_2019',
#  'total_active_commuters_2020',
#  'total_active_commuters_2021',
#  'total_cyclists_2010',
#  'total_cyclists_2011',
#  'total_cyclists_2012',
#  'total_cyclists_2013',
#  'total_cyclists_2014',
#  'total_cyclists_2015',
#  'total_cyclists_2016',
#  'total_cyclists_2017',
#  'total_cyclists_2018',
#  'total_cyclists_2019',
# ...

# %%
commuting_data[commuting_data['B01001_001E_2010'] > 1000000].sort_values(by="change_in_non_wfh_bike_share", ascending=False)[['NAME',
'change_in_active_commuters',
'percent_change_in_active_commuters',
'change_in_active_modeshare',
'change_in_non_wfh_active_modeshare',
'change_in_cyclists',
'percent_change_in_cyclists',
'change_in_bike_share',
'change_in_non_wfh_bike_share',
'metropolitan/micropolitan statistical area',
'total_active_commuters_2010',
'total_active_commuters_2011',
'total_active_commuters_2012',
'total_active_commuters_2013',
'total_active_commuters_2014',
'total_active_commuters_2015',
'total_active_commuters_2016',
'total_active_commuters_2017',
'total_active_commuters_2018',
'total_active_commuters_2019',
'total_active_commuters_2020',
'total_active_commuters_2021',
'total_cyclists_2010',
'total_cyclists_2011',
'total_cyclists_2012',
'total_cyclists_2013',
'total_cyclists_2014',
'total_cyclists_2015',
'total_cyclists_2016',
'total_cyclists_2017',
'total_cyclists_2018',
'total_cyclists_2019',
'total_cyclists_2020',
'total_cyclists_2021',
'percent_of_commuters_active_2010',
'percent_of_commuters_active_2011',
'percent_of_commuters_active_2012',
'percent_of_commuters_active_2013',
'percent_of_commuters_active_2014',
'percent_of_commuters_active_2015',
'percent_of_commuters_active_2016',
'percent_of_commuters_active_2017',
'percent_of_commuters_active_2018',
'percent_of_commuters_active_2019',
'percent_of_commuters_active_2020',
'percent_of_commuters_active_2021',
'bike_share_2010',
'bike_share_2011',
'bike_share_2012',
'bike_share_2013',
'bike_share_2014',
'bike_share_2015',
'bike_share_2016',
'bike_share_2017',
'bike_share_2018',
'bike_share_2019',
'bike_share_2020',
'bike_share_2021',
'percent_of_non_wfh_commuters_active_2010',
'percent_of_non_wfh_commuters_active_2011',
'percent_of_non_wfh_commuters_active_2012',
'percent_of_non_wfh_commuters_active_2013',
'percent_of_non_wfh_commuters_active_2014',
'percent_of_non_wfh_commuters_active_2015',
'percent_of_non_wfh_commuters_active_2016',
'percent_of_non_wfh_commuters_active_2017',
'percent_of_non_wfh_commuters_active_2018',
'percent_of_non_wfh_commuters_active_2019',
'percent_of_non_wfh_commuters_active_2020',
'percent_of_non_wfh_commuters_active_2021',
'non_wfh_bike_share_2010',
'non_wfh_bike_share_2011',
'non_wfh_bike_share_2012',
'non_wfh_bike_share_2013',
'non_wfh_bike_share_2014',
'non_wfh_bike_share_2015',
'non_wfh_bike_share_2016',
'non_wfh_bike_share_2017',
'non_wfh_bike_share_2018',
'non_wfh_bike_share_2019',
'non_wfh_bike_share_2020',
'non_wfh_bike_share_2021'
]].sort_values(by="change_in_non_wfh_bike_share", ascending=False).to_csv("commuting_insights.csv")

# %%
commuting_data[commuting_data['B01001_001E_2010'] > 1000000].sort_values(by="change_in_non_wfh_bike_share", ascending=False)[['change_in_active_commuters',
'percent_change_in_active_commuters',
'change_in_active_modeshare',
'change_in_non_wfh_active_modeshare',
'change_in_cyclists',
'percent_change_in_cyclists',
'change_in_bike_share',
'change_in_non_wfh_bike_share',
'metropolitan/micropolitan statistical area',
'total_active_commuters_2010',
'total_active_commuters_2011',
'total_active_commuters_2012',
'total_active_commuters_2013',
'total_active_commuters_2014',
'total_active_commuters_2015',
'total_active_commuters_2016',
'total_active_commuters_2017',
'total_active_commuters_2018',
'total_active_commuters_2019',
'total_active_commuters_2020',
'total_active_commuters_2021',
'total_cyclists_2010',
'total_cyclists_2011',
'total_cyclists_2012',
'total_cyclists_2013',
'total_cyclists_2014',
'total_cyclists_2015',
'total_cyclists_2016',
'total_cyclists_2017',
'total_cyclists_2018',
'total_cyclists_2019',
'total_cyclists_2020',
'total_cyclists_2021',
'percent_of_commuters_active_2010',
'percent_of_commuters_active_2011',
'percent_of_commuters_active_2012',
'percent_of_commuters_active_2013',
'percent_of_commuters_active_2014',
'percent_of_commuters_active_2015',
'percent_of_commuters_active_2016',
'percent_of_commuters_active_2017',
'percent_of_commuters_active_2018',
'percent_of_commuters_active_2019',
'percent_of_commuters_active_2020',
'percent_of_commuters_active_2021',
'bike_share_2010',
'bike_share_2011',
'bike_share_2012',
'bike_share_2013',
'bike_share_2014',
'bike_share_2015',
'bike_share_2016',
'bike_share_2017',
'bike_share_2018',
'bike_share_2019',
'bike_share_2020',
'bike_share_2021',
'percent_of_non_wfh_commuters_active_2010',
'percent_of_non_wfh_commuters_active_2011',
'percent_of_non_wfh_commuters_active_2012',
'percent_of_non_wfh_commuters_active_2013',
'percent_of_non_wfh_commuters_active_2014',
'percent_of_non_wfh_commuters_active_2015',
'percent_of_non_wfh_commuters_active_2016',
'percent_of_non_wfh_commuters_active_2017',
'percent_of_non_wfh_commuters_active_2018',
'percent_of_non_wfh_commuters_active_2019',
'percent_of_non_wfh_commuters_active_2020',
'percent_of_non_wfh_commuters_active_2021',
'non_wfh_bike_share_2010',
'non_wfh_bike_share_2011',
'non_wfh_bike_share_2012',
'non_wfh_bike_share_2013',
'non_wfh_bike_share_2014',
'non_wfh_bike_share_2015',
'non_wfh_bike_share_2016',
'non_wfh_bike_share_2017',
'non_wfh_bike_share_2018',
'non_wfh_bike_share_2019',
'non_wfh_bike_share_2020',
'non_wfh_bike_share_2021'
]].to_csv("commuting_insights.csv")

# %%
commuting_data[commuting_data['B01001_001E_2010'] > 1000000].sort_values(by="change_in_cyclists", ascending=False)
# Out:
#                                                     NAME  B01001_001E_2010  \
# 35620  New York-Northern New Jersey-Long Island, NY-N...          18700715
# 47900  Washington-Arlington-Alexandria, DC-VA-MD-WV M...           5416691
# 14460          Boston-Cambridge-Quincy, MA-NH Metro Area           4489250
# 41860       San Francisco-Oakland-Fremont, CA Metro Area           4244889
# 16980     Chicago-Joliet-Naperville, IL-IN-WI Metro Area           9384661
# 37980  Philadelphia-Camden-Wilmington, PA-NJ-DE-MD Me...           5911638
# 42660             Seattle-Tacoma-Bellevue, WA Metro Area           3356089
# 19740            Denver-Aurora-Broomfield, CO Metro Area           2464415
# 41940      San Jose-Sunnyvale-Santa Clara, CA Metro Area           1793888
# 35380         New Orleans-Metairie-Kenner, LA Metro Area           1105020
# 12420        Austin-Round Rock-San Marcos, TX Metro Area           1627571
# ...

# %%
commuting_data[(commuting_data['B01001_001E_2010'] > 1000000) & (commuting_data['change_in_active_commuters'] > 0)].sort_values(by="change_in_active_modeshare", ascending=False)[["NAME","change_in_active_commuters","percent_change_in_active_commuters","change_in_active_modeshare"]]
# Out:
#                                                     NAME  \
# 41940      San Jose-Sunnyvale-Santa Clara, CA Metro Area
# 36420                       Oklahoma City, OK Metro Area
# 47260  Virginia Beach-Norfolk-Newport News, VA-NC Met...
# 35380         New Orleans-Metairie-Kenner, LA Metro Area
# 42660             Seattle-Tacoma-Bellevue, WA Metro Area
# 34980  Nashville-Davidson--Murfreesboro--Franklin, TN...
# 26900                 Indianapolis-Carmel, IN Metro Area
# 36740           Orlando-Kissimmee-Sanford, FL Metro Area
# 18140                            Columbus, OH Metro Area
# 19100         Dallas-Fort Worth-Arlington, TX Metro Area
# 39580                        Raleigh-Cary, NC Metro Area
# 41860       San Francisco-Oakland-Fremont, CA Metro Area
# 16740     Charlotte-Gastonia-Rock Hill, NC-SC Metro Area
# 41620                      Salt Lake City, UT Metro Area
# 14460          Boston-Cambridge-Quincy, MA-NH Metro Area
# ...

# %%
commuting_data[commuting_data['B01001_001E_2010'] > 1000000].sort_values(by="percent_of_commuters_active_2021", ascending=False)[["NAME","total_active_commuters_2021","change_in_active_commuters","percent_change_in_active_commuters","change_in_active_modeshare"]]
# Out:
#                                                     NAME  \
# 35620  New York-Northern New Jersey-Long Island, NY-N...
# 41860       San Francisco-Oakland-Fremont, CA Metro Area
# 14460          Boston-Cambridge-Quincy, MA-NH Metro Area
# 47900  Washington-Arlington-Alexandria, DC-VA-MD-WV M...
# 16980     Chicago-Joliet-Naperville, IL-IN-WI Metro Area
# 42660             Seattle-Tacoma-Bellevue, WA Metro Area
# 37980  Philadelphia-Camden-Wilmington, PA-NJ-DE-MD Me...
# 38900     Portland-Vancouver-Hillsboro, OR-WA Metro Area
# 38300                          Pittsburgh, PA Metro Area
# 12580                    Baltimore-Towson, MD Metro Area
# 41940      San Jose-Sunnyvale-Santa Clara, CA Metro Area
# 33460  Minneapolis-St. Paul-Bloomington, MN-WI Metro ...
# 19740            Denver-Aurora-Broomfield, CO Metro Area
# 41740       San Diego-Carlsbad-San Marcos, CA Metro Area
# 15380               Buffalo-Niagara Falls, NY Metro Area
# ...

# %%
commuting_data.sort_values(by="change_in_active_commuters", ascending=False).head(30)
# Out:
#                                                     NAME  B01001_001E_2010  \
# 41860       San Francisco-Oakland-Fremont, CA Metro Area           4244889
# 42660             Seattle-Tacoma-Bellevue, WA Metro Area           3356089
# 35620  New York-Northern New Jersey-Long Island, NY-N...          18700715
# 14460          Boston-Cambridge-Quincy, MA-NH Metro Area           4489250
# 41940      San Jose-Sunnyvale-Santa Clara, CA Metro Area           1793888
# 17900                            Columbia, SC Metro Area            744145
# 24340                Grand Rapids-Wyoming, MI Metro Area            772621
# 22780                   Fort Leonard Wood, MO Micro Area             49114
# 16740     Charlotte-Gastonia-Rock Hill, NC-SC Metro Area           1687440
# 12420        Austin-Round Rock-San Marcos, TX Metro Area           1627571
# 22180                        Fayetteville, NC Metro Area            357122
# ...

# %%
# Out:
# /tmp/ipykernel_70256/4194900397.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   commuting_data['B08006_001E_2018']['21580']=1

# %%
commuting_data
# Out:
#                                            NAME  B01001_001E_2010  \
# 36580                    Oneonta, NY Micro Area             62604
# 36620                 Ontario, OR-ID Micro Area             53777
# 36660           Opelousas-Eunice, LA Micro Area             84309
# 36700                 Orangeburg, SC Micro Area             92475
# 36740  Orlando-Kissimmee-Sanford, FL Metro Area           2083626
# ...                                         ...               ...
# 36380                 Okeechobee, FL Micro Area             39883
# 36420              Oklahoma City, OK Metro Area           1218920
# 36460                      Olean, NY Micro Area             80776
# 36500                    Olympia, WA Metro Area            243563
# 36540    Omaha-Council Bluffs, NE-IA Metro Area            845820
#
#        B08006_001E_2010  B08006_002E_2010  B08006_003E_2010  B08006_004E_2010  \
# 36580             28657             23694             20645              3049
# ...

# %%
df_2010.index
# Out:
# Index(['36580', '36620', '36660', '36700', '36740', '36780', '36820', '36860',
#        '36900', '36940',
#        ...
#        '36180', '36220', '36260', '36300', '36340', '36380', '36420', '36460',
#        '36500', '36540'],
#       dtype='object', length=955)

# %%
commuting_data.sort_values(by="percent_of_commuters_active_2021", ascending=False)
# Out:
#                                                     NAME  B01001_001E_2010  \
# 35620  New York-Northern New Jersey-Long Island, NY-N...          18700715
# 22780                   Fort Leonard Wood, MO Micro Area             49114
# 39420                             Pullman, WA Micro Area             43747
# 41860       San Francisco-Oakland-Fremont, CA Metro Area           4244889
# 27060                              Ithaca, NY Metro Area            100612
# ...                                                  ...               ...
# 20540                           Dyersburg, TN Micro Area             38174
# 11380                             Andrews, TX Micro Area             14048
# 43180                         Shelbyville, TN Micro Area             44172
# 46180                              Tupelo, MS Micro Area            134298
# 37780                               Pecos, TX Micro Area             13269
#
# ...

# %%
commuting_data
# Out:
#                                            NAME B01001_001E_2010  \
# 36580                    Oneonta, NY Micro Area            62604
# 36620                 Ontario, OR-ID Micro Area            53777
# 36660           Opelousas-Eunice, LA Micro Area            84309
# 36700                 Orangeburg, SC Micro Area            92475
# 36740  Orlando-Kissimmee-Sanford, FL Metro Area          2083626
# ...                                         ...              ...
# 36380                 Okeechobee, FL Micro Area            39883
# 36420              Oklahoma City, OK Metro Area          1218920
# 36460                      Olean, NY Micro Area            80776
# 36500                    Olympia, WA Metro Area           243563
# 36540    Omaha-Council Bluffs, NE-IA Metro Area           845820
#
#       B08006_001E_2010 B08006_002E_2010 B08006_003E_2010 B08006_004E_2010  \
# 36580            28657            23694            20645             3049
# ...

# %%
temp_2
# Out:
# '35620'

# %%
df_2010['NAME']['35620']
# Out:
# 'New York-Northern New Jersey-Long Island, NY-NJ-PA Metro Area'

# %%
df_2021['NAME']['35620']
# Out:
# 'New York-Newark-Jersey City, NY-NJ-PA Metro Area'

# %%
commuting_data['total_active_commuters_2020']['35620']
# Out:
# 0

# %%
commuting_data['percent_of_commuters_active_2020']['35620']
# Out:
# 0.0

# %%
commuting_data[commuting_data['NAME']=="New York-Northern New Jersey-Long Island, NY-NJ-PA Metro Area"]
# Out:
#                                                     NAME B01001_001E_2010  \
# 35620  New York-Northern New Jersey-Long Island, NY-N...         18700715
#
#       B08006_001E_2010 B08006_002E_2010 B08006_003E_2010 B08006_004E_2010  \
# 35620          8675198          4993657          4368477           625180
#
#       B08006_005E_2010 B08006_006E_2010 B08006_007E_2010 B08006_008E_2010  \
# 35620           458275            87039            79866          2642480
#
#       B08006_009E_2010 B08006_010E_2010 B08006_011E_2010 B08006_012E_2010  \
# 35620           739806            17387          1547352           320496
#
#       B08006_013E_2010 B08006_014E_2010 B08006_015E_2010 B08006_016E_2010  \
# 35620            17439            37652           533170           143928
#
#       B08006_017E_2010  \
# 35620           324311
#
#       metropolitan statistical area/micropolitan statistical area_x  \
# 35620                                              35620
#
# ...
